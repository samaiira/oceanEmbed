# %% [markdown]
# # Final Evaluation
#
# Phase 9: Compare all models and generate final evaluation report.

# %%
import os
import yaml
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ## Load All Trained Models

# %%
# TODO: Load checkpoints for all models
# from src.models.oceanembed_model import load_model_from_checkpoint
# models = {
#     'CNN MVP': load_model_from_checkpoint('checkpoints/cnn_mvp.pt'),
#     'CNN Temporal': load_model_from_checkpoint('checkpoints/cnn_temporal.pt'),
#     'ConvLSTM': load_model_from_checkpoint('checkpoints/convlstm.pt'),
#     'ViT': load_model_from_checkpoint('checkpoints/vit.pt'),
# }

# %% [markdown]
# ## Evaluate All Models on Test Set

# %%
# TODO: Run inference on test set for all models
# from src.evaluation.metrics import compute_all_metrics
# results = {}
# for name, model in models.items():
#     predictions = ... # inference
#     metrics = compute_all_metrics(predictions, test_targets)
#     results[name] = metrics

# %% [markdown]
# ## Compare Metrics

# %%
# TODO: Create comparison table
# results_df = pd.DataFrame(results).T
# print(results_df)
# results_df.to_csv('outputs/metrics/model_comparison.csv')

# %% [markdown]
# ## Plot RMSE by Depth

# %% [markdown]
# ## Profile Predictions

# %%
# TODO: Overlay predicted vs actual profiles
# from src.evaluation.plot_profiles import plot_profile_comparison
# fig = plot_profile_comparison(predictions['ViT'], test_targets, depths)
# plt.savefig('outputs/figures/profile_comparison.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## Uncertainty Estimates

# %%
# TODO: Compute and visualize MC Dropout uncertainties
# from src.evaluation.uncertainty import UncertaintyEstimator
# estimator = UncertaintyEstimator(models['ViT'], num_samples=50)
# mean_preds, std_preds = estimator.estimate_uncertainty(test_inputs)

# %% [markdown]
# ## Generate Final Report

# %%
# TODO: Write summary report
# report = f"""
# # OceanEmbed Final Evaluation Report
# 
# ## Best Model: ViT
# - RMSE: {results['ViT']['rmse']}
# - Correlation: {results['ViT']['correlation']}
# 
# ## Key Findings
# ...
# """
# with open('outputs/FINAL_REPORT.md', 'w') as f:
#     f.write(report)
