# %% [markdown]
# # Train Continuous Decoder
#
# Phase 6: Add physical loss constraints (smoothness, monotonicity) and train continuous-depth decoder.
#
# **Run on Kaggle**.

# %%
import os
import yaml
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Pretrained Model from Phase 5

# %%
# TODO: Load pretrained model
# from src.models.oceanembed_model import load_model_from_checkpoint
# model = load_model_from_checkpoint('checkpoints/cnn_temporal.pt')

# %% [markdown]
# ## Replace Decoder with Continuous-Depth Version

# %%
# TODO: Replace decoder, keep encoder frozen or fine-tune
# from src.models.decoder import MLPDecoder
# model.decoder = MLPDecoder(continuous=True)
# # Freeze encoder
# for param in model.encoder.parameters():
#     param.requires_grad = False

# %% [markdown]
# ## Define Physical Loss Functions

# %%
# TODO: Use PhysicalLosses with smoothness + monotonicity
# from src.losses.physical_losses import PhysicalLosses
# loss_fn = PhysicalLosses(smoothness_weight=0.1, monotonicity_weight=0.1)

# %% [markdown]
# ## Train with Physical Constraints

# %%
# TODO: Training loop with physical loss
# from src.training.train import train_model
# trained_model, history = train_model(config, dataloaders['train'], dataloaders['val'], model)

# %% [markdown]
# ## Evaluate Smoothness

# %%
# TODO: Visualize predicted profiles to check smoothness
# predictions = ... # model inference
# for i in range(10):
#     plt.plot(predictions[i], label=f'Profile {i}')
# plt.xlabel('Depth')
# plt.ylabel('Temperature')
# plt.title('Predicted Profiles (Continuous Depth)')
# plt.show()
