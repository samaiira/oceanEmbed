# %% [markdown]
# # Train CNN MVP
#
# Phase 4: Train baseline CNN encoder-decoder model on fixed-depth temperature predictions.
#
# **Run on Kaggle** for GPU access.

# %%
import os
import sys
import yaml
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Config

# %%
# TODO: Load config/model_config.yaml
# with open('config/model_config.yaml', 'r') as f:
#     config = yaml.safe_load(f)
# print(config)

# %% [markdown]
# ## Create DataLoaders

# %%
# TODO: Load dataset, create train/val/test DataLoaders
# from src.data.dataset import OceanEmbedDataset, get_dataloaders
# dataloaders = get_dataloaders('data/processed/', batch_size=config['training']['batch_size'])

# %% [markdown]
# ## Initialize Model

# %%
# TODO: Create CNN encoder-decoder model
# from src.models.oceanembed_model import OceanEmbedModel
# model = OceanEmbedModel(encoder_type='cnn', decoder_type='mlp', ...)
# model = model.to('cuda')
# print(model)

# %% [markdown]
# ## Train

# %%
# TODO: Training loop
# from src.training.train import train_model
# trained_model, history = train_model(config, dataloaders['train'], dataloaders['val'], model)
# torch.save(trained_model.state_dict(), 'checkpoints/cnn_mvp.pt')

# %% [markdown]
# ## Plot Training History

# %%
# TODO: Plot train/val loss
# plt.plot(history['train_loss'], label='Train')
# plt.plot(history['val_loss'], label='Val')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.title('CNN MVP Training History')
# plt.show()

# %% [markdown]
# ## Evaluate on Test Set

# %%
# TODO: Compute metrics on test set
# from src.evaluation.metrics import compute_all_metrics
# predictions = ... # model inference
# targets = ... # test targets
# metrics = compute_all_metrics(predictions, targets)
# print(metrics)
