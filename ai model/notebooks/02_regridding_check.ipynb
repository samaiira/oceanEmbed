# %% [markdown]
# # Regridding Check
#
# Phase 2: Verify that all datasets are correctly regridded to common 0.25° grid.

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ## Load Regridded Data

# %%
# TODO: Load regridded datasets from data/interim/
# sst_regridded = xr.open_dataset('data/interim/sst_0.25.nc')
# print(sst_regridded)

# %% [markdown]
# ## Check Grid Resolution

# %%
# TODO: Verify grid spacing
# lat_spacing = np.diff(sst_regridded.lat.values).mean()
# lon_spacing = np.diff(sst_regridded.lon.values).mean()
# print(f"Lat spacing: {lat_spacing}, Lon spacing: {lon_spacing}")

# %% [markdown]
# ## Visualize Regridded Data

# %%
# TODO: Plot regridded SST on one day
# sst_regridded.sst.isel(time=0).plot(cmap='RdBu_r')
# plt.title('Regridded SST (Day 0)')
# plt.show()

# %% [markdown]
# ## Compare Before/After Regridding

# %%
# TODO: Load raw and regridded data, compare side-by-side
# raw_sst = xr.open_dataset('data/raw/sst/*.nc')
# regridded_sst = xr.open_dataset('data/interim/sst_0.25.nc')
# print(f"Raw shape: {raw_sst.sst.shape}")
# print(f"Regridded shape: {regridded_sst.sst.shape}")
