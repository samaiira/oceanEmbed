# %% [markdown]
# # Train ConvLSTM and Transformer
#
# Phase 7: Train ConvLSTM and Vision Transformer encoders on temporal sequences.
#
# **Run on rented GPU** (better for larger temporal sequences).

# %%
import os
import yaml
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# ## ConvLSTM Experiment

# %%
# TODO: Create ConvLSTM model
# from src.models.oceanembed_model import OceanEmbedModel
# model_convlstm = OceanEmbedModel(encoder_type='convlstm', decoder_type='mlp', ...)
# model_convlstm = model_convlstm.to('cuda')

# %%
# TODO: Train ConvLSTM
# from src.training.train import train_model
# trained_convlstm, history_convlstm = train_model(config, dataloaders['train'], dataloaders['val'], model_convlstm)
# torch.save(trained_convlstm.state_dict(), 'checkpoints/convlstm.pt')

# %% [markdown]
# ## Vision Transformer Experiment

# %%
# TODO: Create ViT model
# model_vit = OceanEmbedModel(encoder_type='transformer', decoder_type='mlp', ...)
# model_vit = model_vit.to('cuda')

# %%
# TODO: Train ViT
# trained_vit, history_vit = train_model(config, dataloaders['train'], dataloaders['val'], model_vit)
# torch.save(trained_vit.state_dict(), 'checkpoints/vit.pt')

# %% [markdown]
# ## Compare Training Curves

# %%
# TODO: Plot train/val loss for both models
# fig, axes = plt.subplots(1, 2, figsize=(14, 5))
# axes[0].plot(history_convlstm['val_loss'], label='ConvLSTM')
# axes[0].plot(history_vit['val_loss'], label='ViT')
# axes[0].set_ylabel('Validation Loss')
# axes[0].legend()
# plt.show()
