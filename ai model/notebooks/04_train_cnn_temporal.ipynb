# %% [markdown]
# # Train CNN with Temporal Features
#
# Phase 5: Train CNN with temporal stacking (last 7 days) and positional encodings.
#
# **Run on Kaggle**.

# %%
import os
import sys
import yaml
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Config

# %%
# TODO: Load config with temporal settings
# with open('config/model_config.yaml', 'r') as f:
#     config = yaml.safe_load(f)

# %% [markdown]
# ## Create Temporal Features

# %%
# TODO: Create temporal stack (7-day lookback)
# from src.features.temporal_stack import create_temporal_stack
# temporal_data = create_temporal_stack(data, lookback_days=7)

# %% [markdown]
# ## Add Positional Encodings

# %%
# TODO: Add lat/lon and day-of-year positional encodings
# from src.features.positional_encoding import encode_lat_lon, encode_day_of_year
# lat_enc = encode_lat_lon(lats, lons, d_model=64)
# doy_enc = encode_day_of_year(dates, d_model=64)

# %% [markdown]
# ## Train CNN with Temporal Features

# %%
# TODO: Create model with temporal input channels
# from src.models.oceanembed_model import OceanEmbedModel
# model = OceanEmbedModel(encoder_type='cnn', decoder_type='mlp', 
#                         encoder_config={'in_channels': 6 * 7 + 128})  # temporal stack + encodings
# model = model.to('cuda')

# %% [markdown]
# ## Training
